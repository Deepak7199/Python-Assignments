# %% [markdown]
# # Conditionals in Python (Beginner Level)
#
# This notebook covers:
# - What are conditionals?
# - if, elif, else
# - Comparison operators
# - Simple examples
# - 10 beginner practice questions

# %% [markdown]
# ## 1. What Are Conditionals?
# Conditionals help Python make decisions based on conditions.

# %% [markdown]
# ## 2. Basic `if` Example

# %%
age = 20
if age >= 18:
    print("Adult")

# %% [markdown]
# ## 3. `if` and `else` Example

# %%
age = 15
if age >= 18:
    print("Adult")
else:
    print("Minor")

# %% [markdown]
# ## 4. `elif` Example

# %%
marks = 72
if marks >= 90:
    print("A Grade")
elif marks >= 75:
    print("B Grade")
else:
    print("C Grade")

# %% [markdown]
# ## 5. Comparison Operators

# %% [markdown]
# | Operator | Meaning |
# |---------|---------|
# | == | equal to |
# | != | not equal to |
# | > | greater than |
# | < | less than |
# | >= | greater than or equal |
# | <= | less than or equal |

# %% [markdown]
# ## 6. Simple Examples

# %%
num = 6
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
temp = 40
if temp > 35:
    print("It's hot")
else:
    print("Normal weather")

# %% [markdown]
# # Practice Questions

# %% [markdown]
# Given:
#
# ### bmi = 27
#
#
# Use conditions:
#
# BMI < 18.5 → "Underweight"
#
# BMI < 25 → "Normal"
#
# Else → "Overweight"

# %%
#Answer here
bmi = float(input("Enter bmi : "))

if bmi < 18.5:
  print("Underweight")
elif bmi < 25:
  print("Normal")
else:
  print("over-weight")
# Out:
# Enter bmi : 21
# Normal

# %% [markdown]
# ## Q. Electricity Bill Alert

# %% [markdown]
# ### units = 310
#
#
# Print:
#
# “Normal Usage” if units <= 200
#
# “High Usage” if units <= 300
#
# “Very High Usage” otherwise

# %%
#answer here
units = float(input("Enter unit used : "))

if units <= 200:
  print("Normal Usage")
elif units <= 300:
  print("Hign Usage")
else:
  print("Very High Usage")
# Out:
# Enter unit used : 245.6
# Hign Usage

# %% [markdown]
# Smartphone Battery Checker

# %% [markdown]
# Given:
#
# battery = 12
#
#
# Print:
#
# “Battery Low” if battery < 20
#
# “Battery Medium” if battery < 80
#
# “Battery Full” otherwise

# %%
battery = int(input("Enter battery left in mobile : "))

if battery < 20:
  print("Battery Low")
elif battery < 80:
  print("Battery Medium")
else:
  print("Battery Full")
# Out:
# Enter battery left in mobile : 25
# Battery Medium
